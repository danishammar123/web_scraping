# %% [markdown]
# # **Web_Scraping_BeautifulSoup_CarDealer**

# %% [markdown]
# **PART 1**: https://www.youtube.com/watch?v=NkFc1nWGBg0
#
# **PART 2**: https://www.youtube.com/watch?v=NCoQNa2AgkY&t=292s
#
# **GITHUB**: https://github.com/LX-schlee/Web_Scraping_BeautifulSoup_CarDealer/blob/master/BS4_Car_Dealer_Final_Template.ipynb
#
# **URL**: https://www.cars.com/shopping/results/?stock_type=cpo&makes%5B%5D=mercedes_benz&models%5B%5D&list_price_max&maximum_distance=all&zip

# %% [markdown]
# **Imports**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # HTTP Request
# **store website in variable**

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=cpo&makes%5B%5D=mercedes_benz&models%5B%5D=&list_price_max=&maximum_distance=20&zip='

# %% [markdown]
# **Get Request**

# %%
response = requests.get(website)

# %% [markdown]
# **Status Code**

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# **Soup Object**

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# **Results**

# %%
results = soup.find_all('div', {'class' : 'vehicle-card'})

# %%
len(results)
# Out:
# 21

# %% [markdown]
# **Target necessary data**

# %%
# Name
# Mileage
# Dealer Name
# Rating
# Rating Count
# Price

# %% [markdown]
# Name

# %%
results[0].find('h2').get_text()
# Out:
# '2021 Mercedes-Benz AMG A 35 Base'

# %% [markdown]
# Mileage

# %%
results[0].find('div', {'class':'mileage'}).get_text()
# Out:
# '14,733 mi.'

# %% [markdown]
# Dealer Name

# %%
results[0].find('div', {'class':'dealer-name'}).get_text().strip()
# Out:
# 'Mercedes-Benz of South Charlotte'

# %% [markdown]
# Rating

# %%
results[0].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.8'

# %% [markdown]
# Review Count

# %%
results[0].find('span', {'class':'sds-rating__link'}).get_text()
# Out:
# '(1,341 reviews)'

# %% [markdown]
# Price

# %%
results[0].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$46,996'

# %% [markdown]
# # **Put everything together inside a For-Loop**

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:

    # name
    try:
        name.append(result.find('h2').get_text())
    except:
        name.append('n/a')

    # mileage
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('n/a')

    # dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')

    # rating
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')

    # review_count
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')

    #price
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')

# %% [markdown]
# **Create Pandas Dataframe**

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
# 9            Mercedes-Benz of Edison    5.0       4,069    $50,995
# 10           Mercedes-Benz of Edison    5.0       4,069    $58,999
# 11                     Rallye Motors    4.8       4,246    $39,900
# 12            Benzel-Busch Motor Car    4.5       5,344    $50,987
# 13       Mercedes-Benz of Georgetown    4.6         507    $71,968
# 14           Mercedes-Benz of Natick    4.9       2,567    $45,998
# 15                 Sullivan-Parkhill    4.5         436    $33,545
# 16       Mercedes-Benz of Fort Wayne    n/a          50    $69,991
# 17    Mercedes-Benz of North Olmsted    4.7       1,530    $43,653
# 18    Mercedes-Benz of Fort Mitchell    4.8         633    $39,845
# 19          Mercedes-Benz of Pompano    4.5         799    $75,395
# 20        Mercedes-Benz of Chantilly    4.7         978    $67,100

# %% [markdown]
# **Output in Excel**

# %%
car_dealer.to_excel('car_dealer_single_page.xlsx', index=False)

# %% [markdown]
# # **Part 2 - Pagination**

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range (1,11):

    # website in variable
    website = 'https://www.cars.com/shopping/results/?page='+ str(i) +'&page_size=20&dealer_id=&list_price_max=&list_price_min=&makes[]=mercedes_benz&maximum_distance=20&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&year_min=&zip='

    # request to website
    response = requests.get(website)

    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')

    # results
    results = soup.find_all('div', {'class' : 'vehicle-card'})

    # loop through results
    for result in results:

        # name
        try:
            name.append(result.find('h2').get_text())
        except:
            name.append('n/a')

        # mileage
        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('n/a')

        # dealer_name
        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

        # rating
        try:
            rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
        except:
            rating.append('n/a')

        # review_count
        try:
            review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
        except:
            review_count.append('n/a')

        #price
        try:
            price.append(result.find('span', {'class':'primary-price'}).get_text())
        except:
            price.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                           Name     Mileage  \
# 0    2022 Mercedes-Benz AMG GLC 43 Base 4MATIC   5,047 mi.
# 1       2020 Mercedes-Benz GLS 450 Base 4MATIC  30,739 mi.
# 2           2022 Mercedes-Benz AMG GLB 35 Base  13,007 mi.
# 3           2022 Mercedes-Benz AMG GLB 35 Base  22,815 mi.
# 4      2019 Mercedes-Benz AMG E 53 Base 4MATIC  23,163 mi.
# ..                                         ...         ...
# 205          2022 Mercedes-Benz AMG GT 53 Base   5,138 mi.
# 206           2019 Mercedes-Benz S-Class S 450  32,088 mi.
# 207           2022 Mercedes-Benz E-Class E 350  14,742 mi.
# 208    2020 Mercedes-Benz E-Class E 350 4MATIC  38,608 mi.
# 209         2022 Mercedes-Benz AMG GLB 35 Base  13,310 mi.
#
#                         Dealer Name Rating Review Count     Price
# 0      Mercedes-Benz of Kansas City    4.7         777    $67,894
# 1      Mercedes-Benz of Springfield    4.9         102    $58,899
# 2      Mercedes-Benz of Springfield    4.9         102    $47,395
# 3        Mercedes-Benz of Chantilly    4.7         978    $47,600
# 4    Mercedes-Benz of State College    n/a           2    $59,491
# ..                              ...    ...          ...       ...
# 205   Mercedes-Benz of White Plains    4.3       1,645   $109,000
# 206      Mercedes-Benz of Melbourne    n/a         177    $54,215
# 207      Mercedes-Benz of Melbourne    n/a         177    $49,700
# 208         Mercedes-Benz of Easton    4.6         684    $41,453
# 209        Mercedes-Benz of Modesto    n/a         142    $49,955
#
# [210 rows x 6 columns]

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                           Name     Mileage  \
# 0    2022 Mercedes-Benz AMG GLC 43 Base 4MATIC   5,047 mi.
# 1       2020 Mercedes-Benz GLS 450 Base 4MATIC  30,739 mi.
# 2           2022 Mercedes-Benz AMG GLB 35 Base  13,007 mi.
# 3           2022 Mercedes-Benz AMG GLB 35 Base  22,815 mi.
# 4      2019 Mercedes-Benz AMG E 53 Base 4MATIC  23,163 mi.
# ..                                         ...         ...
# 205          2022 Mercedes-Benz AMG GT 53 Base   5,138 mi.
# 206           2019 Mercedes-Benz S-Class S 450  32,088 mi.
# 207           2022 Mercedes-Benz E-Class E 350  14,742 mi.
# 208    2020 Mercedes-Benz E-Class E 350 4MATIC  38,608 mi.
# 209         2022 Mercedes-Benz AMG GLB 35 Base  13,310 mi.
#
#                         Dealer Name Rating Review Count     Price
# 0      Mercedes-Benz of Kansas City    4.7         777    $67,894
# 1      Mercedes-Benz of Springfield    4.9         102    $58,899
# 2      Mercedes-Benz of Springfield    4.9         102    $47,395
# 3        Mercedes-Benz of Chantilly    4.7         978    $47,600
# 4    Mercedes-Benz of State College    n/a           2    $59,491
# ..                              ...    ...          ...       ...
# 205   Mercedes-Benz of White Plains    4.3       1,645   $109,000
# 206      Mercedes-Benz of Melbourne    n/a         177    $54,215
# 207      Mercedes-Benz of Melbourne    n/a         177    $49,700
# 208         Mercedes-Benz of Easton    4.6         684    $41,453
# 209        Mercedes-Benz of Modesto    n/a         142    $49,955
#
# [210 rows x 6 columns]

# %%
car_dealer.to_excel('car_dealer_multi_page.xlsx', index=False)

# %% [markdown]
# end of the project: as on 26th july 2023
